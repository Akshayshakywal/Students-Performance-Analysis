# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
data = {"Name":["akshay","bhanu","prakash"],"age":[22,23,22]}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  age
# 0   akshay   22
# 1    bhanu   23
# 2  prakash   22

# %%
data = pd.read_csv("C:/Users/aksha/Downloads/StudentsPerformance.csv")
#print(data)
print(data.head(10))
#print(data.tail(10))
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        990 non-null    object
#  4   test preparation course      986 non-null    object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
# None

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
print(data.isnull().sum())
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                          10
# test preparation course        14
# math score                      0
# reading score                   0
# writing score                   0
# dtype: int64

# %%
#task01

# %%
print(data["gender"].duplicated().sum())
# Out:
# 998

# %%
import numpy as np

# %%
#print(data.fillna(method = "ffill"))
data["lunch"] = data["lunch"].replace(np.nan,"free/reduced")
print(data)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
print(data.isnull().sum())
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course        14
# math score                      0
# reading score                   0
# writing score                   0
# dtype: int64

# %%
#print(data.fillna(method = "ffill"))
data["test preparation Course"] = data["test preparation course"].replace(np.nan,"completed")
#print(data)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
print(data.isnull().sum())
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course        14
# math score                      0
# reading score                   0
# writing score                   0
# test preparation Course         0
# dtype: int64

# %%
#task02.1

# %%
gender_performance = data.groupby('gender')[['math score', 'reading score', 'writing score']].mean()
print("average score by gender:")
print(gender_performance)
# Out:
# average score by gender:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
import matplotlib.pyplot as plt

# %%
gender_performance.plot(kind='bar', figsize=(10, 6), color=['black', 'purple', 'green'])
plt.title('Average Scores by Gender in Math, Reading, and Writing')
plt.ylabel('Average Score')
plt.xlabel('Gender')
plt.xticks(rotation=0)
plt.legend(title='Subjects')
plt.show()

# %%
#TASK2.2

# %%
# Group data by parental level of education and calculate mean scores for Math, Reading, and Writing
education_performance = data.groupby('parental level of education')[['math score', 'reading score', 'writing score']].mean()

# Display the results
print("Average scores by parental education level:")
print(education_performance)
# Out:
# Average scores by parental education level:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %%
# Visualization: Plot the average scores for each parental education level
education_performance.plot(kind='bar', figsize=(12, 6), color=['yellow', 'black', 'blue'])
plt.title('Average Scores by Parental Level of Education')
plt.ylabel('Average Score')
plt.xlabel('Parental Level of Education')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Subjects')
plt.show()

# %%
#TASK3.2

# %%
# Group data by gender and parental level of education
grouped_data = data.groupby(['gender', 'parental level of education'])

# Create a list of students for each group
students_grouped = grouped_data.apply(lambda x: x.to_dict('records')).tolist()

# Display the first few grouped records as an example
print("Example grouped data:")
print(students_grouped[:2])  # Show only the first two groups for brevity
# Out:
# Example grouped data:
# ...

# %%
#TASK04

# %%
# Group data by gender and parental level of education
grouped_data = data.groupby(['gender', 'parental level of education'])[['math score', 'reading score', 'writing score']].mean()

# Convert the grouped data into a dictionary
average_scores_dict = grouped_data.to_dict(orient='index')

# Display the dictionary
print("Average scores grouped by gender and parental level of education:")
for key, value in average_scores_dict.items():
    print(f"{key}: {value}")
# Out:
# Average scores grouped by gender and parental level of education:
# ('female', "associate's degree"): {'math score': 65.25, 'reading score': 74.12068965517241, 'writing score': 74.0}
# ('female', "bachelor's degree"): {'math score': 68.34920634920636, 'reading score': 77.28571428571429, 'writing score': 78.38095238095238}
# ('female', 'high school'): {'math score': 59.351063829787236, 'reading score': 68.20212765957447, 'writing score': 66.69148936170212}
# ('female', "master's degree"): {'math score': 66.5, 'reading score': 76.80555555555556, 'writing score': 77.63888888888889}
# ('female', 'some college'): {'math score': 65.40677966101696, 'reading score': 73.55084745762711, 'writing score': 74.05084745762711}
# ('female', 'some high school'): {'math score': 59.2967032967033, 'reading score': 69.10989010989012, 'writing score': 68.28571428571429}
# ...

# %%
#TASK3.1

# %%
# Group data by lunch type and calculate the average scores
lunch_performance = data.groupby('lunch')[['math score', 'reading score', 'writing score']].mean()

# Group data by test preparation course and calculate the average scores
prep_course_performance = data.groupby('test preparation course')[['math score', 'reading score', 'writing score']].mean()

# Display the results
print("Average scores by lunch type:")
print(lunch_performance)
print("\nAverage scores by test preparation course completion:")
print(prep_course_performance)

# Visualize the results for lunch type
lunch_performance.plot(kind='bar', figsize=(10, 6), color=['blue', 'orange', 'green'])
plt.title('Average Scores by Lunch Type')
plt.ylabel('Average Score')
plt.xlabel('Lunch Type')
plt.xticks(rotation=0)
plt.legend(title='Subjects')
plt.show()

# Visualize the results for test preparation course
prep_course_performance.plot(kind='bar', figsize=(10, 6), color=['purple', 'pink', 'teal'])
plt.title('Average Scores by Test Preparation Course Completion')
plt.ylabel('Average Score')
plt.xlabel('Test Preparation Course')
plt.xticks(rotation=0)
plt.legend(title='Subjects')
plt.show()
# Out:
# Average scores by lunch type:
#               math score  reading score  writing score
# lunch
# free/reduced   59.297521      64.898072      63.322314
# standard       69.959184      71.602826      70.750392
#
# Average scores by test preparation course completion:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.702550      73.951841      74.444759
# none                      64.052133      66.522907      64.497630

# %%
#task02

# %%
# Grouping students by lunch type and converting each group into a list of dictionaries
students_by_lunch = data.groupby('lunch').apply(lambda x: x.to_dict('records')).to_dict()

# Grouping students by test preparation course and converting each group into a list of dictionaries
students_by_prep_course = data.groupby('test preparation course').apply(lambda x: x.to_dict('records')).to_dict()

# Calculating average scores by lunch type
avg_scores_by_lunch = data.groupby('lunch')[['math score', 'reading score', 'writing score']].mean().to_dict(orient='index')

# Calculating average scores by test preparation course
avg_scores_by_prep_course = data.groupby('test preparation course')[['math score', 'reading score', 'writing score']].mean().to_dict(orient='index')

# Displaying the results
print("Students grouped by lunch type:")
for lunch_type, students in students_by_lunch.items():
    print(f"\nLunch Type: {lunch_type} | Number of Students: {len(students)}")
    print(f"Average Scores: {avg_scores_by_lunch[lunch_type]}")

print("\nStudents grouped by test preparation course:")
for prep_course, students in students_by_prep_course.items():
    print(f"\nTest Preparation Course: {prep_course} | Number of Students: {len(students)}")
    print(f"Average Scores: {avg_scores_by_prep_course[prep_course]}")
# Out:
# Students grouped by lunch type:
#
# Lunch Type: free/reduced | Number of Students: 363
# Average Scores: {'math score': 59.29752066115702, 'reading score': 64.89807162534436, 'writing score': 63.32231404958678}
#
# Lunch Type: standard | Number of Students: 637
# Average Scores: {'math score': 69.95918367346938, 'reading score': 71.60282574568289, 'writing score': 70.75039246467819}
#
# Students grouped by test preparation course:
#
# Test Preparation Course: completed | Number of Students: 353
# Average Scores: {'math score': 69.70254957507082, 'reading score': 73.95184135977337, 'writing score': 74.44475920679886}
#
# Test Preparation Course: none | Number of Students: 633
# Average Scores: {'math score': 64.0521327014218, 'reading score': 66.52290679304897, 'writing score': 64.49763033175356}

# %%
#task04

# %%
# Visualization of average scores by gender and race/ethnicity
grouped_data.unstack().plot(kind='bar', figsize=(14, 8))
plt.title('Average Scores by Gender and Race/Ethnicity')
plt.ylabel('Average Score')
plt.xlabel('Groups')
plt.legend(title='Subjects')
plt.xticks(rotation=45)
plt.show()
